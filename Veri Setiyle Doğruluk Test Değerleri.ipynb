# %%
# -*- coding: utf-8 -*-

#YSA Uygulama

#1.Kütüphaneleri yükle

#numpy kütüphanesi matematiksel işlemler

import numpy as np

# pandas kütüphanesi verisetini yüklerken

import pandas as pd

# 2.Veri setimizi yükleyelim

dataset=pd.read_csv("veriseti4.csv")

#Girdileri değişkene atayalım.

X=dataset.iloc[ : , 3:13 ].values

#Çıktıları değişkene atayalım.
y=dataset.iloc[:,13].values


#Eksik veri kontrolu?

dataset.isnull().sum()

#kategorik verileri çevirme

from sklearn.preprocessing import LabelEncoder

labelencoder_X_1=LabelEncoder()
labelencoder_X_2=LabelEncoder()

X[:,1]=labelencoder_X_1.fit_transform(X[:,1])


X[:,2]=labelencoder_X_2.fit_transform(X[:,2])

#Dumy Encoding

from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer

transformer=make_column_transformer((OneHotEncoder(drop='first'),[1,2]),remainder='passthrough')

X=transformer.fit_transform(X)

#5. Adım Veri setini eğitim ve test olarak ayır.

from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=60)


#6. Adım özellik ölçeklendirme

from sklearn.preprocessing import StandardScaler

sc_X=StandardScaler()

X_train=sc_X.fit_transform(X_train)
X_test=sc_X.fit_transform(X_test)

#YAPAY SINIR AGIMIZI OLUSTURALIM

from keras.models import Sequential
from keras.layers import Dense

model=Sequential()

model.add(Dense(units=10,kernel_initializer='uniform', activation='relu', input_dim=11))
          
model.add(Dense(units=5,activation='relu',kernel_initializer='uniform'))  

model.add(Dense(units=1, activation='sigmoid', kernel_initializer='uniform'))   

model.summary()

model.compile(optimizer='adam', loss='binary_crossentropy',metrics=['accuracy'])

#MOdeli eğitme
model.fit(X_train,y_train,epochs=10,batch_size=10)
model.fit(X_train, y_train, epochs=100, batch_size=10)

y_pred=model.predict(X_test)

y_pred2=(y_pred>0.5)

from sklearn.metrics import confusion_matrix

cm=confusion_matrix(y_test,y_pred2)

test_accuracy=(1940+163)/(1940+45+352+163)
print(test_accuracy)
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_24 (Dense)            (None, 10)                120
#
#  dense_25 (Dense)            (None, 5)                 55
#
#  dense_26 (Dense)            (None, 1)                 6
#
# ...
# Total params: 181
# Trainable params: 181
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 750/750 [==============================] - 2s 2ms/step - loss: 0.4972 - accuracy: 0.7973
# Epoch 2/10
# 750/750 [==============================] - 1s 2ms/step - loss: 0.4102 - accuracy: 0.8256
# Epoch 3/10
# 750/750 [==============================] - 1s 2ms/step - loss: 0.3950 - accuracy: 0.8287
# Epoch 4/10
# 750/750 [==============================] - 1s 2ms/step - loss: 0.3852 - accuracy: 0.8304
# Epoch 5/10
# ...

# %%
# import pandas 
import pandas 

# create dataframe 
pandas.DataFrame({'a': [1, 2]})
# Out:
#    a
# 0  1
# 1  2

# %%
pip install module_name
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install scikit-learn

# %%
# -*- coding: utf-8 -*-

#YSA Uygulama

#1.Kütüphaneleri yükle

#numpy kütüphanesi matematiksel işlemler

import numpy as np

# pandas kütüphanesi verisetini yüklerken

import pandas as pd

# 2.Veri setimizi yükleyelim

dataset=pd.read_csv("veriseti4.csv")

#Girdileri değişkene atayalım.

X=dataset.iloc[ : , 3:13 ].values

#Çıktıları değişkene atayalım.
y=dataset.iloc[:,13].values


#Eksik veri kontrolu?

dataset.isnull().sum()

#kategorik verileri çevirme

from sklearn.preprocessing import LabelEncoder

labelencoder_X_1=LabelEncoder()
labelencoder_X_2=LabelEncoder()

X[:,1]=labelencoder_X_1.fit_transform(X[:,1])


X[:,2]=labelencoder_X_2.fit_transform(X[:,2])

#Dumy Encoding

from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer

transformer=make_column_transformer((OneHotEncoder(drop='first'),[1,2]),remainder='passthrough')

X=transformer.fit_transform(X)

#5. Adım Veri setini eğitim ve test olarak ayır.

from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=60)


#6. Adım özellik ölçeklendirme

from sklearn.preprocessing import StandardScaler

sc_X=StandardScaler()

X_train=sc_X.fit_transform(X_train)
X_test=sc_X.fit_transform(X_test)

#YAPAY SINIR AGIMIZI OLUSTURALIM

from keras.models import Sequential
from keras.layers import Dense

model=Sequential()

model.add(Dense(units=10,kernel_initializer='uniform', activation='relu', input_dim=11))
          
model.add(Dense(units=5,activation='relu',kernel_initializer='uniform'))  

model.add(Dense(units=1, activation='sigmoid', kernel_initializer='uniform'))   

model.summary()

model.compile(optimizer='adam', loss='binary_crossentropy',metrics=['accuracy'])

#MOdeli eğitme
model.fit(X_train,y_train,epochs=10,batch_size=10)
model.fit(X_train, y_train, epochs=100, batch_size=10)

y_pred=model.predict(X_test)

y_pred2=(y_pred>0.5)

from sklearn.metrics import confusion_matrix

cm=confusion_matrix(y_test,y_pred2)
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_15 (Dense)            (None, 10)                120
#
#  dense_16 (Dense)            (None, 5)                 55
#
#  dense_17 (Dense)            (None, 1)                 6
#
# ...
# Total params: 181
# Trainable params: 181
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 750/750 [==============================] - 3s 2ms/step - loss: 0.4804 - accuracy: 0.7971
# Epoch 2/10
# 750/750 [==============================] - 1s 2ms/step - loss: 0.4280 - accuracy: 0.7971
# Epoch 3/10
# 750/750 [==============================] - 1s 2ms/step - loss: 0.4226 - accuracy: 0.8016
# Epoch 4/10
# 750/750 [==============================] - 1s 2ms/step - loss: 0.4194 - accuracy: 0.8223
# Epoch 5/10
# ...
